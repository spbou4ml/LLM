# %% [markdown]
# <a href="https://colab.research.google.com/github/spbou4ml/LLM/blob/main/Starling-LM-7B-alpha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Modelex.io
# ## Starling-LM-7B-alpha

# %%
import transformers

tokenizer = transformers.AutoTokenizer.from_pretrained("berkeley-nest/Starling-LM-7B-alpha")
model = transformers.AutoModelForCausalLM.from_pretrained("berkeley-nest/Starling-LM-7B-alpha")
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.61k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/560 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# ...
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/115 [00:00<?, ?B/s]

# %%
def generate_response(prompt):
    input_ids = tokenizer(prompt, return_tensors="pt").input_ids
    outputs = model.generate(
        input_ids,
        max_length=256,
        pad_token_id=tokenizer.pad_token_id,
        eos_token_id=tokenizer.eos_token_id,
    )
    response_ids = outputs[0]
    response_text = tokenizer.decode(response_ids, skip_special_tokens=True)
    return response_text

# %%
prompt = "écris moi un poème"
single_turn_prompt = f"User: {prompt}<|end_of_turn|>Assistant:"
response_text = generate_response(single_turn_prompt)
print("Response:", response_text)
# Out:
# Response: User: écris moi un poème Assistant: Dans la nuit, les étoiles brillent,
#
# Le ciel est un tableau d'art,
#
# Les nuages flottent dans le vent,
#
# Et les rêves s'envolent sans fin.
#
# Les montagnes, elles s'élancent,
#
# Vers le ciel, vers les étoiles,
#
# Et les vallées, elles s'ouvrent,
#
# Aux secrets et aux mystères du monde.
#
# Le soleil, il se lève, il se couche,
#
# Il éclaire nos jours et nos nuits,
#
# Et nous, les êtres humains, nous vivons,
#
# Dans la beauté et la douceur de la vie.
#
# Les fleurs, elles fleurissent, elles s'épanouissent,
#
# Elles donnent à nos jardins leur parfum,
#
# Et les arbres, ils s'étendent,
#
# Vers le ciel, vers les étoiles, vers les rêves.
